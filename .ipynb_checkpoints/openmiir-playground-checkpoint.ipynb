# %% [markdown]
# # Data preprocessing and artifact removal

# %% [markdown]
# Nous nous sommes basé sur [Ce tutorial](https://mne.tools/stable/auto_tutorials/preprocessing/plot_40_artifact_correction_ica.html#sphx-glr-auto-tutorials-preprocessing-plot-40-artifact-correction-ica-py). Les composantes indépendantes utilisées ici sont  celles calculées dans le [repo](https://github.com/sstober/openmiir/tree/master/eeg/preprocessing) du dataset.

# %% [markdown]
# The data :
# -  5 blocks that each comprised all 12 stimuli in randomized order: 60 perception trials per subject.
# - EEG was recorded with a BioSemi Active-Two system using 64+2 EEG channels at 512 Hz.
# - Hor- izontal and vertical electrooculography (EOG) channels were used to record eye movements.
#
# To do :
#
# - remove and interpolate bad EEG channels (between 0 and 3 per subject) identified by manual visual inspection.
# - Filter with a bandpass keeping a frequency range between 0.5 and 30 Hz ( this also remove any slow signal drift in the EEG)
# - To remove artifacts caused by eye blinks, we computed ICA  and semi-automatically removed components that had a high correlation with the EOG channels.
# - Reconstruct from the remaining independent components without reducing dimensionality.
# - all trial channels were additionally normalized to zero mean and range [−1, 1].

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from mne.preprocessing import read_ica, ICA
import os
# Out:
# /kaggle/input/openmiir/README.md
# /kaggle/input/openmiir/.gitignore
# /kaggle/input/openmiir/scripts/README.md
# /kaggle/input/openmiir/scripts/presentation/OpenMIIR_StimulusPresentation.m
# /kaggle/input/openmiir/scripts/presentation/README.md
# /kaggle/input/openmiir/scripts/presentation/music.mat
# /kaggle/input/openmiir/scripts/eeglab/fif2mat.py
# /kaggle/input/openmiir/scripts/eeglab/import_raw.m
# /kaggle/input/openmiir/scripts/eeglab/biosemi64_NoM.locs
# /kaggle/input/openmiir/logo/OpenMIIR-logo_transparent_728x265.png
# /kaggle/input/openmiir/eeg/OpenMIIR-RawEEG_v1.torrent
# /kaggle/input/openmiir/eeg/preprocessing/README.md
# /kaggle/input/openmiir/eeg/preprocessing/notebooks/Subject P04.ipynb
# /kaggle/input/openmiir/eeg/preprocessing/notebooks/Subject P01.ipynb
# /kaggle/input/openmiir/eeg/preprocessing/notebooks/Subject P05.ipynb
# /kaggle/input/openmiir/eeg/preprocessing/notebooks/Subject P12.ipynb
# /kaggle/input/openmiir/eeg/preprocessing/notebooks/Subject P09.ipynb
# /kaggle/input/openmiir/eeg/preprocessing/notebooks/Subject P06.ipynb
# /kaggle/input/openmiir/eeg/preprocessing/notebooks/Subject P13.ipynb
# /kaggle/input/openmiir/eeg/preprocessing/notebooks/Subject P11.ipynb
# /kaggle/input/openmiir/eeg/preprocessing/notebooks/Subject P14.ipynb
# /kaggle/input/openmiir/eeg/preprocessing/notebooks/Subject P07.ipynb
# /kaggle/input/openmiir/eeg/preprocessing/ica/P06-100p_64c-ica.fif
# /kaggle/input/openmiir/eeg/preprocessing/ica/P07-100p_64c-ica.fif
# /kaggle/input/openmiir/eeg/preprocessing/ica/P13-100p_64c-ica.fif
# /kaggle/input/openmiir/eeg/preprocessing/ica/P11-100p_64c-ica.fif
# /kaggle/input/openmiir/eeg/preprocessing/ica/P09-100p_64c-ica.fif
# /kaggle/input/openmiir/eeg/preprocessing/ica/P04-100p_64c-ica.fif
# /kaggle/input/openmiir/eeg/preprocessing/ica/P14-100p_64c-ica.fif
# /kaggle/input/openmiir/eeg/preprocessing/ica/P01-100p_64c-ica.fif
# /kaggle/input/openmiir/eeg/preprocessing/ica/P12-100p_64c-ica.fif
# /kaggle/input/openmiir/eeg/mne/README.md
# /kaggle/input/openmiir/meta/README.md
# /kaggle/input/openmiir/meta/electrode_info.xlsx
# /kaggle/input/openmiir/meta/Stimuli_Meta.v1.xlsx
# /kaggle/input/openmiir/meta/Stimuli_Meta.v2.xlsx
# /kaggle/input/openmiir/meta/beats.v2/24_beats.txt
# /kaggle/input/openmiir/meta/beats.v2/2_cue_beats.txt
# /kaggle/input/openmiir/meta/beats.v2/22_beats.txt
# /kaggle/input/openmiir/meta/beats.v2/24_cue_beats.txt
# /kaggle/input/openmiir/meta/beats.v2/3_beats.txt
# /kaggle/input/openmiir/meta/beats.v2/1_beats.txt
# /kaggle/input/openmiir/meta/beats.v2/2_beats.txt
# /kaggle/input/openmiir/meta/beats.v2/3_cue_beats.txt
# /kaggle/input/openmiir/meta/beats.v2/12_beats.txt
# /kaggle/input/openmiir/meta/beats.v2/22_cue_beats.txt
# /kaggle/input/openmiir/meta/beats.v2/21_beats.txt
# /kaggle/input/openmiir/meta/beats.v2/11_beats.txt
# /kaggle/input/openmiir/meta/beats.v2/23_cue_beats.txt
# /kaggle/input/openmiir/meta/beats.v2/14_cue_beats.txt
# /kaggle/input/openmiir/meta/beats.v2/11_cue_beats.txt
# /kaggle/input/openmiir/meta/beats.v2/1_cue_beats.txt
# /kaggle/input/openmiir/meta/beats.v2/12_cue_beats.txt
# /kaggle/input/openmiir/meta/beats.v2/4_cue_beats.txt
# /kaggle/input/openmiir/meta/beats.v2/14_beats.txt
# /kaggle/input/openmiir/meta/beats.v2/13_cue_beats.txt
# /kaggle/input/openmiir/meta/beats.v2/13_beats.txt
# /kaggle/input/openmiir/meta/beats.v2/21_cue_beats.txt
# /kaggle/input/openmiir/meta/beats.v2/4_beats.txt
# /kaggle/input/openmiir/meta/beats.v2/23_beats.txt
# /kaggle/input/openmiir/meta/beats.v1/24_beats.txt
# /kaggle/input/openmiir/meta/beats.v1/2_cue_beats.txt
# /kaggle/input/openmiir/meta/beats.v1/22_beats.txt
# /kaggle/input/openmiir/meta/beats.v1/24_cue_beats.txt
# /kaggle/input/openmiir/meta/beats.v1/3_beats.txt
# /kaggle/input/openmiir/meta/beats.v1/1_beats.txt
# /kaggle/input/openmiir/meta/beats.v1/2_beats.txt
# /kaggle/input/openmiir/meta/beats.v1/3_cue_beats.txt
# /kaggle/input/openmiir/meta/beats.v1/12_beats.txt
# /kaggle/input/openmiir/meta/beats.v1/22_cue_beats.txt
# /kaggle/input/openmiir/meta/beats.v1/21_beats.txt
# /kaggle/input/openmiir/meta/beats.v1/11_beats.txt
# /kaggle/input/openmiir/meta/beats.v1/23_cue_beats.txt
# /kaggle/input/openmiir/meta/beats.v1/14_cue_beats.txt
# /kaggle/input/openmiir/meta/beats.v1/11_cue_beats.txt
# /kaggle/input/openmiir/meta/beats.v1/1_cue_beats.txt
# /kaggle/input/openmiir/meta/beats.v1/12_cue_beats.txt
# /kaggle/input/openmiir/meta/beats.v1/4_cue_beats.txt
# /kaggle/input/openmiir/meta/beats.v1/14_beats.txt
# /kaggle/input/openmiir/meta/beats.v1/13_cue_beats.txt
# /kaggle/input/openmiir/meta/beats.v1/13_beats.txt
# /kaggle/input/openmiir/meta/beats.v1/21_cue_beats.txt
# /kaggle/input/openmiir/meta/beats.v1/4_beats.txt
# /kaggle/input/openmiir/meta/beats.v1/23_beats.txt
# /kaggle/input/openmiir/questionnaire/README.md
# /kaggle/input/openmiir/questionnaire/QuestionnaireScores.xls
# /kaggle/input/openmiir/questionnaire/Questionnaire.pdf
# /kaggle/input/openmiir/audio/README.md
# /kaggle/input/openmiir/audio/cues.v2/S12_Take Me Out To The Ballgame_no lyrics_cue.wav
# /kaggle/input/openmiir/audio/cues.v2/S13_Jingle Bells_no lyrics_cue.wav
# /kaggle/input/openmiir/audio/cues.v2/S04_Mary Had A Little Lamb_lyrics_cue.wav
# /kaggle/input/openmiir/audio/cues.v2/S21_EmperorWaltz_cue.wav
# /kaggle/input/openmiir/audio/cues.v2/S01_Chim Chim Cheree_lyrics_cue.wav
# /kaggle/input/openmiir/audio/cues.v2/S23_Star Wars Theme_cue.wav
# /kaggle/input/openmiir/audio/cues.v2/S24_Eine kleine Nachtmusic_cue.wav
# /kaggle/input/openmiir/audio/cues.v2/S14_Mary Had A Little Lamb_no lyrics_cue.wav
# /kaggle/input/openmiir/audio/cues.v2/S03_Jingle Bells_lyrics_cue.wav
# /kaggle/input/openmiir/audio/cues.v2/S22_Harry Potter Theme_cue.wav
# /kaggle/input/openmiir/audio/cues.v2/S11_Chim Chim Cheree_no lyrics_cue.wav
# /kaggle/input/openmiir/audio/cues.v2/S02_Take Me Out To The Ballgame_lyrics_cue.wav
# /kaggle/input/openmiir/audio/full.v1/makelinks.sh
# /kaggle/input/openmiir/audio/full.v1/README.md
# /kaggle/input/openmiir/audio/full.v1/S11_Chim Chim Cheree_no lyrics.wav
# /kaggle/input/openmiir/audio/full.v1/S22_Harry Potter Theme.wav
# /kaggle/input/openmiir/audio/full.v1/S02_Take Me Out To The Ballgame_lyrics.wav
# /kaggle/input/openmiir/audio/full.v1/S01_Chim Chim Cheree_lyrics.wav
# /kaggle/input/openmiir/audio/full.v1/S12_Take Me Out To The Ballgame_no lyrics.wav
# /kaggle/input/openmiir/audio/full.v2/S24_Eine kleine Nachtmusic.wav
# /kaggle/input/openmiir/audio/full.v2/S03_Jingle Bells_lyrics.wav
# /kaggle/input/openmiir/audio/full.v2/README.md
# /kaggle/input/openmiir/audio/full.v2/S13_Jingle Bells_no lyrics.wav
# /kaggle/input/openmiir/audio/full.v2/S21_EmperorWaltz.wav
# /kaggle/input/openmiir/audio/full.v2/S11_Chim Chim Cheree_no lyrics.wav
# /kaggle/input/openmiir/audio/full.v2/S22_Harry Potter Theme.wav
# /kaggle/input/openmiir/audio/full.v2/S14_Mary Had A Little Lamb_no lyrics.wav
# /kaggle/input/openmiir/audio/full.v2/S04_Mary Had A Little Lamb_lyrics.wav
# /kaggle/input/openmiir/audio/full.v2/S02_Take Me Out To The Ballgame_lyrics.wav
# /kaggle/input/openmiir/audio/full.v2/S01_Chim Chim Cheree_lyrics.wav
# /kaggle/input/openmiir/audio/full.v2/S23_Star Wars Theme.wav
# /kaggle/input/openmiir/audio/full.v2/S12_Take Me Out To The Ballgame_no lyrics.wav
# /kaggle/input/openmiir/audio/cues.v1/S12_Take Me Out To The Ballgame_no lyrics_cue.wav
# /kaggle/input/openmiir/audio/cues.v1/makelinks.sh
# /kaggle/input/openmiir/audio/cues.v1/S01_Chim Chim Cheree_lyrics_cue.wav
# /kaggle/input/openmiir/audio/cues.v1/README.md
# /kaggle/input/openmiir/audio/cues.v1/S22_Harry Potter Theme_cue.wav
# /kaggle/input/openmiir/audio/cues.v1/S11_Chim Chim Cheree_no lyrics_cue.wav
# /kaggle/input/openmiir/audio/cues.v1/S02_Take Me Out To The Ballgame_lyrics_cue.wav
# /kaggle/input/openmiir/pylearn2/README.md
# /kaggle/input/rawsbeforehoes/P04-raw.fif
# /kaggle/input/rawsbeforehoes/P13-raw.fif
# /kaggle/input/rawsbeforehoes/P01-raw.fif
# /kaggle/input/rawsbeforehoes/P14-raw.fif
# /kaggle/input/rawsbeforehoes/P06-raw.fif
# /kaggle/input/rawsbeforehoes/P11-raw.fif
# /kaggle/input/rawsbeforehoes/P09-raw.fif
# /kaggle/input/rawsbeforehoes/P07-raw.fif
# /kaggle/input/rawsbeforehoes/P05-raw.fif
# /kaggle/input/rawsbeforehoes/P12-raw.fif

# %%
pip install mne
# Out:
# Collecting mne
#   Downloading https://files.pythonhosted.org/packages/c9/0d/ba12e84feae362d9808e51aa4e3d96a148db9a047e13e51bb070016fa1ab/mne-0.21.0-py3-none-any.whl (6.8MB)
#     100% |████████████████████████████████| 6.8MB 226kB/s ta 0:00:01
# Collecting numpy>=1.11.3 (from mne)
#   Downloading https://files.pythonhosted.org/packages/b8/e5/a64ef44a85397ba3c377f6be9c02f3cb3e18023f8c89850dd319e7945521/numpy-1.19.2-cp36-cp36m-manylinux1_x86_64.whl (13.4MB)
#     100% |████████████████████████████████| 13.4MB 118kB/s eta 0:00:01
# Collecting scipy>=0.17.1 (from mne)
#   Downloading https://files.pythonhosted.org/packages/2b/a8/f4c66eb529bb252d50e83dbf2909c6502e2f857550f22571ed8556f62d95/scipy-1.5.2-cp36-cp36m-manylinux1_x86_64.whl (25.9MB)
#     100% |████████████████████████████████| 25.9MB 63kB/s  eta 0:00:01
# Installing collected packages: numpy, scipy, mne

# %%
import matplotlib.pyplot as plt
import mne
from mne import read_proj
from mne.io import read_raw_fif
from mne.datasets import sample
import os
ROOT = os.getcwd()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-b5045a3dd81c> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 import mne
#       3 from mne import read_proj
#       4 from mne.io import read_raw_fif
#       5 from mne.datasets import sample
#
# ModuleNotFoundError: No module named 'mne'

# %%
path = "/kaggle/input/rawsbeforehoes/P01-raw.fif"
raw = mne.io.read_raw_fif(path,preload=True)
# Out:
# Opening raw data file /kaggle/input/rawsbeforehoes/P01-raw.fif...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 64)  idle
#     Range : 0 ... 2478165 =      0.000 ...  4840.166 secs
# Ready.
# Reading 0 ... 2478165  =      0.000 ...  4840.166 secs...

# %%
raw.info
# Out:
# <Info | 11 non-empty values
#  bads: 3 items (P8, P10, T8)
#  ch_names: Fp1, AF7, AF3, F1, F3, F5, F7, FT7, FC5, FC3, FC1, C1, C3, C5, ...
#  chs: 64 EEG, 4 EOG, 1 STIM
#  custom_ref_applied: False
#  file_id: 4 items (dict)
#  highpass: 0.0 Hz
#  lowpass: 104.0 Hz
#  meas_date: 2015-01-28 17:39:57 UTC
#  meas_id: 4 items (dict)
#  nchan: 69
#  projs: Average EEG reference: off
#  sfreq: 512.0 Hz
# >

# %%
raw.plot()

# %%
ica = read_ica('/kaggle/input/openmiir/eeg/preprocessing/ica/P01-100p_64c-ica.fif')
# Out:
# Reading /kaggle/input/openmiir/eeg/preprocessing/ica/P01-100p_64c-ica.fif ...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 64)  idle
# Now restoring ICA solution ...
# Ready.

# %%
ica.plot_components()
# Out:
# [<Figure size 702x678.24 with 20 Axes>,
#  <Figure size 702x678.24 with 20 Axes>,
#  <Figure size 702x678.24 with 20 Axes>,
#  <Figure size 140.4x169.56 with 1 Axes>]

# %%
ica.plot_sources(raw)

# %%
reconst_raw = raw.copy()
s = ica.apply(reconst_raw)
# Out:
# Transforming to ICA space (61 components)
# Zeroing out 4 ICA components

# %%
X = raw.get_data()
X_clean = s.get_data()

# %%
sfreq = raw.info['sfreq']

# %%
from pylab import *
plot(X[1, 0:int(10 * sfreq)])

# %%
raw.plot(n_channels = 2, scalings = 'auto')

# %%
plot(X_clean[0])

# %%
raw.plot_psd()
# Out:
# Effective window size : 4.000 (s)

# %%
reconst_raw.plot_psd()
# Out:
# Effective window size : 4.000 (s)

# %%
plot(X_clean[0])

# %%
reconst_raw.plot(duration=20.0, start=0.0, n_channels=1)

# %%
# show some frontal channels to clearly illustrate the artifact removal
chs = raw.ch_names
chan_idxs = [raw.ch_names.index(ch) for ch in chs]
raw.plot(order=chan_idxs, start=12, duration=4)
reconst_raw.plot(order=chan_idxs, start=12, duration=4)
